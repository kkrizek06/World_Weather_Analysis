# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
#create set random lat and long combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#create list for holding cities
cities = []

#Identify the nearest city each lat and long
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city unique then add city to list
    if city not in cities:
        cities.append(city)
#print city count
len(cities)
# Out:
# 751

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | sechura
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | cockburn town
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | sao filipe
# Processing Record 8 of Set 1 | fortuna
# Processing Record 9 of Set 1 | chhindwara
# Processing Record 10 of Set 1 | leningradskiy
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | lakes entrance
# Processing Record 14 of Set 1 | kruisfontein
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | luanda
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | phrae
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | ulladulla
# Processing Record 25 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 1 | orocue
# Processing Record 27 of Set 1 | cedar rapids
# Processing Record 28 of Set 1 | robertsport
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | loznica
# Processing Record 34 of Set 1 | malinovoye ozero
# Processing Record 35 of Set 1 | tocopilla
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | patu
# Processing Record 38 of Set 1 | anshun
# Processing Record 39 of Set 1 | rundu
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | takoradi
# Processing Record 44 of Set 1 | nishihara
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | fort-shevchenko
# Processing Record 47 of Set 1 | bilma
# Processing Record 48 of Set 1 | lata
# Processing Record 49 of Set 1 | kushima
# Processing Record 50 of Set 1 | katsuura
# Processing Record 1 of Set 2 | ankara
# Processing Record 2 of Set 2 | ixtapa
# Processing Record 3 of Set 2 | lebedyn
# Processing Record 4 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | gander
# Processing Record 8 of Set 2 | nelson bay
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | avera
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | polson
# Processing Record 13 of Set 2 | sidi ali
# Processing Record 14 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 2 | maldonado
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | bolshaya atnya
# City not found. Skipping...
# Processing Record 19 of Set 2 | ternate
# Processing Record 20 of Set 2 | wanxian
# Processing Record 21 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | talnakh
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | arona
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | port augusta
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | turtas
# Processing Record 31 of Set 2 | bambous virieux
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | vao
# Processing Record 34 of Set 2 | tuktoyaktuk
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | shimoda
# Processing Record 37 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 38 of Set 2 | te anau
# Processing Record 39 of Set 2 | yulara
# Processing Record 40 of Set 2 | nhulunbuy
# Processing Record 41 of Set 2 | geraldton
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | fruitville
# Processing Record 44 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 2 | saint-augustin
# Processing Record 46 of Set 2 | jining
# Processing Record 47 of Set 2 | nemuro
# Processing Record 48 of Set 2 | dingle
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 1 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 3 | san quintin
# Processing Record 3 of Set 3 | port keats
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | arlit
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | codrington
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | airai
# Processing Record 12 of Set 3 | dhanera
# Processing Record 13 of Set 3 | daru
# Processing Record 14 of Set 3 | turtkul
# City not found. Skipping...
# Processing Record 15 of Set 3 | makakilo city
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | niquelandia
# Processing Record 18 of Set 3 | dunedin
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | kirakira
# Processing Record 22 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 3 | langham
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | ringkobing
# Processing Record 27 of Set 3 | mount gambier
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | oksbol
# Processing Record 30 of Set 3 | algiers
# Processing Record 31 of Set 3 | naze
# Processing Record 32 of Set 3 | hambantota
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | pokhara
# Processing Record 36 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 3 | grao mogol
# Processing Record 38 of Set 3 | namibe
# Processing Record 39 of Set 3 | svetlaya
# Processing Record 40 of Set 3 | nicoya
# Processing Record 41 of Set 3 | provideniya
# Processing Record 42 of Set 3 | jambi
# Processing Record 43 of Set 3 | hami
# Processing Record 44 of Set 3 | meulaboh
# Processing Record 45 of Set 3 | gushikawa
# Processing Record 46 of Set 3 | nome
# Processing Record 47 of Set 3 | craig
# Processing Record 48 of Set 3 | almaznyy
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | nokaneng
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | marsa matruh
# Processing Record 3 of Set 4 | soe
# Processing Record 4 of Set 4 | tombouctou
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | tadine
# Processing Record 7 of Set 4 | mahebourg
# Processing Record 8 of Set 4 | nanortalik
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | carutapera
# Processing Record 11 of Set 4 | hasaki
# Processing Record 12 of Set 4 | chicama
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | andijon
# Processing Record 15 of Set 4 | san antonio
# Processing Record 16 of Set 4 | gorontalo
# Processing Record 17 of Set 4 | numazu
# Processing Record 18 of Set 4 | witbank
# Processing Record 19 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 4 | salinopolis
# Processing Record 21 of Set 4 | ojinaga
# Processing Record 22 of Set 4 | chase
# Processing Record 23 of Set 4 | rocha
# Processing Record 24 of Set 4 | coihaique
# Processing Record 25 of Set 4 | chipinge
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | uige
# Processing Record 29 of Set 4 | bom jesus
# Processing Record 30 of Set 4 | ketchikan
# Processing Record 31 of Set 4 | beloha
# Processing Record 32 of Set 4 | turukhansk
# Processing Record 33 of Set 4 | acapulco
# Processing Record 34 of Set 4 | mao
# Processing Record 35 of Set 4 | zdunska wola
# Processing Record 36 of Set 4 | shaping
# Processing Record 37 of Set 4 | tommot
# Processing Record 38 of Set 4 | sibolga
# Processing Record 39 of Set 4 | praia
# Processing Record 40 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 4 | sabha
# Processing Record 42 of Set 4 | linares
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | ormara
# Processing Record 45 of Set 4 | yarmouth
# Processing Record 46 of Set 4 | abu kamal
# Processing Record 47 of Set 4 | kaitangata
# Processing Record 48 of Set 4 | alizai
# Processing Record 49 of Set 4 | castro
# Processing Record 50 of Set 4 | tazovskiy
# Processing Record 1 of Set 5 | kununurra
# Processing Record 2 of Set 5 | coahuayana
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | vanimo
# Processing Record 6 of Set 5 | singkawang
# Processing Record 7 of Set 5 | taoudenni
# Processing Record 8 of Set 5 | zambezi
# Processing Record 9 of Set 5 | kutum
# Processing Record 10 of Set 5 | igarka
# Processing Record 11 of Set 5 | kerema
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 5 | port alfred
# Processing Record 14 of Set 5 | rimini
# Processing Record 15 of Set 5 | vardo
# Processing Record 16 of Set 5 | minot
# Processing Record 17 of Set 5 | cidreira
# Processing Record 18 of Set 5 | san-pedro
# Processing Record 19 of Set 5 | benguela
# Processing Record 20 of Set 5 | havelock
# Processing Record 21 of Set 5 | majene
# Processing Record 22 of Set 5 | hanna
# Processing Record 23 of Set 5 | grand-santi
# Processing Record 24 of Set 5 | bereda
# Processing Record 25 of Set 5 | oriximina
# Processing Record 26 of Set 5 | dumai
# Processing Record 27 of Set 5 | waipawa
# Processing Record 28 of Set 5 | saint anthony
# Processing Record 29 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 30 of Set 5 | kushiro
# Processing Record 31 of Set 5 | mitzic
# Processing Record 32 of Set 5 | evansville
# Processing Record 33 of Set 5 | college
# Processing Record 34 of Set 5 | paralimni
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | marzuq
# Processing Record 37 of Set 5 | cookeville
# Processing Record 38 of Set 5 | husavik
# Processing Record 39 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 40 of Set 5 | lukovetskiy
# Processing Record 41 of Set 5 | maniitsoq
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | mount isa
# Processing Record 44 of Set 5 | vila velha
# Processing Record 45 of Set 5 | san juan
# Processing Record 46 of Set 5 | laguna
# Processing Record 47 of Set 5 | la ronge
# Processing Record 48 of Set 5 | los llanos de aridane
# Processing Record 49 of Set 5 | labrea
# Processing Record 50 of Set 5 | dawei
# Processing Record 1 of Set 6 | vestmannaeyjar
# Processing Record 2 of Set 6 | pangkalanbuun
# Processing Record 3 of Set 6 | alexandria
# Processing Record 4 of Set 6 | sitka
# Processing Record 5 of Set 6 | makrana
# Processing Record 6 of Set 6 | storm lake
# Processing Record 7 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 6 | viedma
# Processing Record 9 of Set 6 | victoria
# Processing Record 10 of Set 6 | amarante do maranhao
# Processing Record 11 of Set 6 | thompson
# Processing Record 12 of Set 6 | shelburne
# Processing Record 13 of Set 6 | lompoc
# Processing Record 14 of Set 6 | krasnouralsk
# Processing Record 15 of Set 6 | rosarito
# Processing Record 16 of Set 6 | alice springs
# Processing Record 17 of Set 6 | lagoa
# Processing Record 18 of Set 6 | dukat
# Processing Record 19 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 6 | comodoro rivadavia
# Processing Record 21 of Set 6 | punta alta
# Processing Record 22 of Set 6 | dhidhdhoo
# Processing Record 23 of Set 6 | russell
# Processing Record 24 of Set 6 | port macquarie
# Processing Record 25 of Set 6 | teknaf
# Processing Record 26 of Set 6 | huarmey
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | alyangula
# Processing Record 29 of Set 6 | diffa
# Processing Record 30 of Set 6 | panorama
# Processing Record 31 of Set 6 | boueni
# Processing Record 32 of Set 6 | mount pleasant
# Processing Record 33 of Set 6 | barcelona
# Processing Record 34 of Set 6 | balikpapan
# Processing Record 35 of Set 6 | keti bandar
# Processing Record 36 of Set 6 | bytow
# Processing Record 37 of Set 6 | huilong
# Processing Record 38 of Set 6 | ilulissat
# Processing Record 39 of Set 6 | kalmunai
# Processing Record 40 of Set 6 | mackay
# Processing Record 41 of Set 6 | papar
# Processing Record 42 of Set 6 | ponta do sol
# Processing Record 43 of Set 6 | tilichiki
# Processing Record 44 of Set 6 | antofagasta
# Processing Record 45 of Set 6 | port hedland
# Processing Record 46 of Set 6 | lingao
# Processing Record 47 of Set 6 | tessalit
# Processing Record 48 of Set 6 | kavieng
# Processing Record 49 of Set 6 | tasiilaq
# Processing Record 50 of Set 6 | la plata
# Processing Record 1 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 7 | safaga
# Processing Record 3 of Set 7 | whitehorse
# Processing Record 4 of Set 7 | sfantu gheorghe
# Processing Record 5 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 6 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 7 of Set 7 | pisco
# Processing Record 8 of Set 7 | currais novos
# Processing Record 9 of Set 7 | naryan-mar
# Processing Record 10 of Set 7 | atasu
# Processing Record 11 of Set 7 | dickinson
# Processing Record 12 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 7 | ratnagiri
# Processing Record 14 of Set 7 | huacho
# Processing Record 15 of Set 7 | cache creek
# Processing Record 16 of Set 7 | thinadhoo
# Processing Record 17 of Set 7 | ullapool
# Processing Record 18 of Set 7 | khatanga
# Processing Record 19 of Set 7 | matay
# Processing Record 20 of Set 7 | rezekne
# Processing Record 21 of Set 7 | backo petrovo selo
# Processing Record 22 of Set 7 | kamenskiy
# Processing Record 23 of Set 7 | ngunguru
# Processing Record 24 of Set 7 | port lincoln
# Processing Record 25 of Set 7 | svobodnyy
# Processing Record 26 of Set 7 | komsomolskiy
# Processing Record 27 of Set 7 | natal
# Processing Record 28 of Set 7 | beyla
# Processing Record 29 of Set 7 | saint-pierre
# Processing Record 30 of Set 7 | norman wells
# Processing Record 31 of Set 7 | nieuw amsterdam
# Processing Record 32 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 7 | raudeberg
# Processing Record 34 of Set 7 | portobelo
# Processing Record 35 of Set 7 | pichayevo
# Processing Record 36 of Set 7 | poum
# Processing Record 37 of Set 7 | aklavik
# Processing Record 38 of Set 7 | nsanje
# Processing Record 39 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 40 of Set 7 | quatre cocos
# Processing Record 41 of Set 7 | myitkyina
# Processing Record 42 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 7 | kavaratti
# Processing Record 44 of Set 7 | bose
# Processing Record 45 of Set 7 | namwala
# Processing Record 46 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 7 | jerusalem
# Processing Record 50 of Set 7 | ciudad bolivar
# Processing Record 1 of Set 8 | sinnamary
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | hamilton
# Processing Record 4 of Set 8 | san joaquin
# Processing Record 5 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 6 of Set 8 | port hardy
# Processing Record 7 of Set 8 | plouzane
# Processing Record 8 of Set 8 | manga
# Processing Record 9 of Set 8 | bud
# Processing Record 10 of Set 8 | lishui
# Processing Record 11 of Set 8 | samdrup jongkhar
# Processing Record 12 of Set 8 | san luis
# Processing Record 13 of Set 8 | morgan city
# Processing Record 14 of Set 8 | san clemente
# Processing Record 15 of Set 8 | zemio
# Processing Record 16 of Set 8 | fort nelson
# Processing Record 17 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 8 | berlevag
# Processing Record 19 of Set 8 | sao borja
# Processing Record 20 of Set 8 | walvis bay
# Processing Record 21 of Set 8 | corner brook
# Processing Record 22 of Set 8 | santa marinella
# Processing Record 23 of Set 8 | verkhnevilyuysk
# Processing Record 24 of Set 8 | iqaluit
# Processing Record 25 of Set 8 | atikokan
# Processing Record 26 of Set 8 | tambura
# Processing Record 27 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 28 of Set 8 | salalah
# Processing Record 29 of Set 8 | sri aman
# Processing Record 30 of Set 8 | half moon bay
# Processing Record 31 of Set 8 | constitucion
# Processing Record 32 of Set 8 | waingapu
# Processing Record 33 of Set 8 | rapid valley
# Processing Record 34 of Set 8 | qaqortoq
# Processing Record 35 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 8 | santiago
# Processing Record 37 of Set 8 | pacifica
# Processing Record 38 of Set 8 | yashalta
# Processing Record 39 of Set 8 | dolores
# Processing Record 40 of Set 8 | faya
# Processing Record 41 of Set 8 | pecos
# Processing Record 42 of Set 8 | hay river
# Processing Record 43 of Set 8 | apollonia
# Processing Record 44 of Set 8 | shaowu
# Processing Record 45 of Set 8 | otane
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | romny
# Processing Record 48 of Set 8 | bongaree
# Processing Record 49 of Set 8 | esperance
# Processing Record 50 of Set 8 | krasnoselkup
# Processing Record 1 of Set 9 | san jorge
# Processing Record 2 of Set 9 | manwath
# City not found. Skipping...
# Processing Record 3 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 9 | olean
# Processing Record 5 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 9 | basco
# Processing Record 7 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 9 | ahipara
# Processing Record 9 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 10 of Set 9 | megion
# Processing Record 11 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 9 | urumqi
# Processing Record 13 of Set 9 | tomatlan
# Processing Record 14 of Set 9 | villarrica
# Processing Record 15 of Set 9 | mayya
# Processing Record 16 of Set 9 | yalova
# Processing Record 17 of Set 9 | tual
# Processing Record 18 of Set 9 | coari
# Processing Record 19 of Set 9 | kupang
# Processing Record 20 of Set 9 | kisangani
# Processing Record 21 of Set 9 | capreol
# Processing Record 22 of Set 9 | pacific grove
# Processing Record 23 of Set 9 | qasigiannguit
# Processing Record 24 of Set 9 | monastyrshchina
# Processing Record 25 of Set 9 | mabay
# Processing Record 26 of Set 9 | beira
# Processing Record 27 of Set 9 | paamiut
# Processing Record 28 of Set 9 | baoying
# Processing Record 29 of Set 9 | petropavlovka
# Processing Record 30 of Set 9 | pella
# Processing Record 31 of Set 9 | anadyr
# Processing Record 32 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 33 of Set 9 | skibbereen
# Processing Record 34 of Set 9 | pangody
# Processing Record 35 of Set 9 | udachnyy
# Processing Record 36 of Set 9 | volokolamsk
# Processing Record 37 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 38 of Set 9 | mangrol
# Processing Record 39 of Set 9 | puerto baquerizo moreno
# Processing Record 40 of Set 9 | lasa
# Processing Record 41 of Set 9 | adrar
# Processing Record 42 of Set 9 | avarua
# Processing Record 43 of Set 9 | jijiga
# Processing Record 44 of Set 9 | sobolevo
# Processing Record 45 of Set 9 | quelimane
# Processing Record 46 of Set 9 | songea
# Processing Record 47 of Set 9 | oksfjord
# Processing Record 48 of Set 9 | alekseyevsk
# Processing Record 49 of Set 9 | guerrero negro
# Processing Record 50 of Set 9 | tashtyp
# Processing Record 1 of Set 10 | san patricio
# Processing Record 2 of Set 10 | chinsali
# Processing Record 3 of Set 10 | trelew
# Processing Record 4 of Set 10 | mufulira
# Processing Record 5 of Set 10 | padang
# Processing Record 6 of Set 10 | bac lieu
# Processing Record 7 of Set 10 | boynton beach
# Processing Record 8 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 10 | hovd
# Processing Record 10 of Set 10 | labuhan
# Processing Record 11 of Set 10 | kieta
# Processing Record 12 of Set 10 | woodward
# Processing Record 13 of Set 10 | markova
# Processing Record 14 of Set 10 | engel-yurt
# Processing Record 15 of Set 10 | kamaishi
# Processing Record 16 of Set 10 | abu zabad
# Processing Record 17 of Set 10 | chlorakas
# Processing Record 18 of Set 10 | dolna banja
# City not found. Skipping...
# Processing Record 19 of Set 10 | antsohihy
# Processing Record 20 of Set 10 | lorengau
# Processing Record 21 of Set 10 | myaundzha
# Processing Record 22 of Set 10 | missoula
# Processing Record 23 of Set 10 | kushmurun
# Processing Record 24 of Set 10 | manama
# Processing Record 25 of Set 10 | marshall
# Processing Record 26 of Set 10 | moba
# Processing Record 27 of Set 10 | conceicao das alagoas
# Processing Record 28 of Set 10 | sweetwater
# Processing Record 29 of Set 10 | east london
# Processing Record 30 of Set 10 | santiago de cao
# Processing Record 31 of Set 10 | shakhtinsk
# Processing Record 32 of Set 10 | andros town
# Processing Record 33 of Set 10 | bahir dar
# Processing Record 34 of Set 10 | jumla
# Processing Record 35 of Set 10 | ostrovnoy
# Processing Record 36 of Set 10 | jasper
# Processing Record 37 of Set 10 | grand-lahou
# Processing Record 38 of Set 10 | saldanha
# Processing Record 39 of Set 10 | bergama
# Processing Record 40 of Set 10 | borujan
# City not found. Skipping...
# Processing Record 41 of Set 10 | coquimbo
# Processing Record 42 of Set 10 | zhongshu
# Processing Record 43 of Set 10 | grindavik
# Processing Record 44 of Set 10 | sokolow podlaski
# Processing Record 45 of Set 10 | canico
# Processing Record 46 of Set 10 | albanel
# Processing Record 47 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 10 | tchibanga
# Processing Record 49 of Set 10 | bourg-en-bresse
# Processing Record 50 of Set 10 | vostok
# Processing Record 1 of Set 11 | hanting
# Processing Record 2 of Set 11 | le vauclin
# Processing Record 3 of Set 11 | jiazi
# Processing Record 4 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 11 | alofi
# Processing Record 6 of Set 11 | lavrentiya
# Processing Record 7 of Set 11 | pemangkat
# Processing Record 8 of Set 11 | necochea
# Processing Record 9 of Set 11 | mata
# Processing Record 10 of Set 11 | fare
# Processing Record 11 of Set 11 | roald
# Processing Record 12 of Set 11 | urdoma
# Processing Record 13 of Set 11 | rio gallegos
# Processing Record 14 of Set 11 | bondoukou
# Processing Record 15 of Set 11 | acheng
# Processing Record 16 of Set 11 | sogne
# Processing Record 17 of Set 11 | nioro
# Processing Record 18 of Set 11 | haines junction
# Processing Record 19 of Set 11 | humaita
# Processing Record 20 of Set 11 | hokitika
# Processing Record 21 of Set 11 | galatii bistritei
# Processing Record 22 of Set 11 | bubaque
# Processing Record 23 of Set 11 | swan hill
# Processing Record 24 of Set 11 | tura
# Processing Record 25 of Set 11 | jalu
# Processing Record 26 of Set 11 | norden
# Processing Record 27 of Set 11 | tayoltita
# Processing Record 28 of Set 11 | dunnville
# Processing Record 29 of Set 11 | wajid
# Processing Record 30 of Set 11 | englehart
# Processing Record 31 of Set 11 | mbuji-mayi
# Processing Record 32 of Set 11 | camp verde
# Processing Record 33 of Set 11 | general roca
# Processing Record 34 of Set 11 | halvad
# Processing Record 35 of Set 11 | sorong
# Processing Record 36 of Set 11 | chore
# City not found. Skipping...
# Processing Record 37 of Set 11 | oda
# Processing Record 38 of Set 11 | maunabo
# Processing Record 39 of Set 11 | abong mbang
# Processing Record 40 of Set 11 | kuala terengganu
# Processing Record 41 of Set 11 | tautira
# Processing Record 42 of Set 11 | eyl
# Processing Record 43 of Set 11 | sharan
# Processing Record 44 of Set 11 | angra
# City not found. Skipping...
# Processing Record 45 of Set 11 | samarai
# Processing Record 46 of Set 11 | uddevalla
# Processing Record 47 of Set 11 | ghanzi
# Processing Record 48 of Set 11 | gwadar
# Processing Record 49 of Set 11 | calvinia
# Processing Record 50 of Set 11 | grand gaube
# Processing Record 1 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 2 of Set 12 | champerico
# Processing Record 3 of Set 12 | caravelas
# Processing Record 4 of Set 12 | yazman
# Processing Record 5 of Set 12 | pochutla
# Processing Record 6 of Set 12 | canakkale
# Processing Record 7 of Set 12 | zhigansk
# Processing Record 8 of Set 12 | molina
# Processing Record 9 of Set 12 | margate
# Processing Record 10 of Set 12 | oranjemund
# Processing Record 11 of Set 12 | isangel
# Processing Record 12 of Set 12 | rio grande
# Processing Record 13 of Set 12 | longkou
# Processing Record 14 of Set 12 | tournon-sur-rhone
# Processing Record 15 of Set 12 | erchie
# Processing Record 16 of Set 12 | nouadhibou
# Processing Record 17 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 12 | trairi
# Processing Record 19 of Set 12 | dawlatabad
# Processing Record 20 of Set 12 | rudnya
# Processing Record 21 of Set 12 | jinxi
# Processing Record 22 of Set 12 | znamenskoye
# Processing Record 23 of Set 12 | ridgecrest
# Processing Record 24 of Set 12 | bayir
# Processing Record 25 of Set 12 | lingdong
# Processing Record 26 of Set 12 | murchison
# Processing Record 27 of Set 12 | hvittingfoss
# Processing Record 28 of Set 12 | lianyuan
# Processing Record 29 of Set 12 | kashi
# Processing Record 30 of Set 12 | kainantu
# Processing Record 31 of Set 12 | la palma
# Processing Record 32 of Set 12 | phangnga
# Processing Record 33 of Set 12 | kalabo
# Processing Record 34 of Set 12 | klecevce
# City not found. Skipping...
# Processing Record 35 of Set 12 | polyanka
# Processing Record 36 of Set 12 | osinki
# Processing Record 37 of Set 12 | canutama
# Processing Record 38 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 39 of Set 12 | guaraniacu
# Processing Record 40 of Set 12 | tuensang
# Processing Record 41 of Set 12 | atar
# Processing Record 42 of Set 12 | perth
# Processing Record 43 of Set 12 | jizan
# Processing Record 44 of Set 12 | ardakan
# Processing Record 45 of Set 12 | najran
# Processing Record 46 of Set 12 | shirgaon
# Processing Record 47 of Set 12 | valenca
# Processing Record 48 of Set 12 | vichayal
# City not found. Skipping...
# Processing Record 49 of Set 12 | cap malheureux
# Processing Record 50 of Set 12 | grafton
# Processing Record 1 of Set 13 | northam
# Processing Record 2 of Set 13 | ustye
# Processing Record 3 of Set 13 | sigerfjord
# City not found. Skipping...
# Processing Record 4 of Set 13 | blagoyevo
# Processing Record 5 of Set 13 | gornyy
# Processing Record 6 of Set 13 | karpathos
# Processing Record 7 of Set 13 | bagdarin
# Processing Record 8 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 13 | pitimbu
# Processing Record 10 of Set 13 | belle fourche
# Processing Record 11 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 13 | sogdiondon
# City not found. Skipping...
# Processing Record 13 of Set 13 | ornskoldsvik
# Processing Record 14 of Set 13 | chifeng
# Processing Record 15 of Set 13 | pangnirtung
# Processing Record 16 of Set 13 | povenets
# Processing Record 17 of Set 13 | atchison
# Processing Record 18 of Set 13 | verkhnyaya khava
# Processing Record 19 of Set 13 | nichinan
# Processing Record 20 of Set 13 | mahibadhoo
# Processing Record 21 of Set 13 | opuwo
# Processing Record 22 of Set 13 | bambanglipuro
# Processing Record 23 of Set 13 | grajau
# Processing Record 24 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 13 | naron
# Processing Record 26 of Set 13 | sioux lookout
# Processing Record 27 of Set 13 | lampa
# Processing Record 28 of Set 13 | brainerd
# Processing Record 29 of Set 13 | gat
# Processing Record 30 of Set 13 | acuna
# City not found. Skipping...
# Processing Record 31 of Set 13 | nago
# Processing Record 32 of Set 13 | pingyin
# Processing Record 33 of Set 13 | baghdad
# Processing Record 34 of Set 13 | garowe
# Processing Record 35 of Set 13 | puerto del rosario
# Processing Record 36 of Set 13 | sapao
# City not found. Skipping...
# Processing Record 37 of Set 13 | oyotun
# Processing Record 38 of Set 13 | marsh harbour
# Processing Record 39 of Set 13 | bandarbeyla
# Processing Record 40 of Set 13 | homer
# Processing Record 41 of Set 13 | blajeni
# Processing Record 42 of Set 13 | ibra
# Processing Record 43 of Set 13 | kristiinankaupunki
# Processing Record 44 of Set 13 | killybegs
# Processing Record 45 of Set 13 | inongo
# Processing Record 46 of Set 13 | alta floresta
# Processing Record 47 of Set 13 | vila
# Processing Record 48 of Set 13 | millbrook
# Processing Record 49 of Set 13 | moose factory
# Processing Record 50 of Set 13 | fairbanks
# Processing Record 1 of Set 14 | mucurapo
# Processing Record 2 of Set 14 | chapais
# Processing Record 3 of Set 14 | acari
# Processing Record 4 of Set 14 | filadelfia
# Processing Record 5 of Set 14 | mezhova
# Processing Record 6 of Set 14 | hailar
# Processing Record 7 of Set 14 | aguimes
# Processing Record 8 of Set 14 | minab
# Processing Record 9 of Set 14 | omaruru
# Processing Record 10 of Set 14 | kapfenberg
# Processing Record 11 of Set 14 | abu samrah
# Processing Record 12 of Set 14 | dinghai
# Processing Record 13 of Set 14 | barkly west
# Processing Record 14 of Set 14 | saint-joseph
# Processing Record 15 of Set 14 | huancabamba
# Processing Record 16 of Set 14 | sorland
# Processing Record 17 of Set 14 | aktau
# Processing Record 18 of Set 14 | bardiyah
# Processing Record 19 of Set 14 | tipperary
# Processing Record 20 of Set 14 | guaranda
# Processing Record 21 of Set 14 | severo-yeniseyskiy
# Processing Record 22 of Set 14 | oyama
# Processing Record 23 of Set 14 | palmer
# Processing Record 24 of Set 14 | pontes e lacerda
# Processing Record 25 of Set 14 | multai
# Processing Record 26 of Set 14 | riyadh
# Processing Record 27 of Set 14 | mumford
# Processing Record 28 of Set 14 | anahuac
# Processing Record 29 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 14 | camacha
# Processing Record 31 of Set 14 | tonj
# Processing Record 32 of Set 14 | pilar
# Processing Record 33 of Set 14 | evensk
# Processing Record 34 of Set 14 | teya
# Processing Record 35 of Set 14 | sao jose da coroa grande
# Processing Record 36 of Set 14 | ouahigouya
# Processing Record 37 of Set 14 | ranong
# Processing Record 38 of Set 14 | upata
# Processing Record 39 of Set 14 | manono
# Processing Record 40 of Set 14 | okhotsk
# Processing Record 41 of Set 14 | presidencia roque saenz pena
# Processing Record 42 of Set 14 | kloulklubed
# Processing Record 43 of Set 14 | sakete
# Processing Record 44 of Set 14 | sanming
# Processing Record 45 of Set 14 | colares
# Processing Record 46 of Set 14 | valdivia
# Processing Record 47 of Set 14 | borogontsy
# Processing Record 48 of Set 14 | korla
# Processing Record 49 of Set 14 | rawson
# Processing Record 50 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 15 | ozernovskiy
# Processing Record 2 of Set 15 | sandpoint
# Processing Record 3 of Set 15 | izumo
# Processing Record 4 of Set 15 | ashtian
# Processing Record 5 of Set 15 | tshikapa
# Processing Record 6 of Set 15 | belyy yar
# Processing Record 7 of Set 15 | vila franca do campo
# Processing Record 8 of Set 15 | marrakesh
# Processing Record 9 of Set 15 | malakal
# Processing Record 10 of Set 15 | calama
# Processing Record 11 of Set 15 | ola
# Processing Record 12 of Set 15 | newport
# Processing Record 13 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 15 | ust-nera
# Processing Record 15 of Set 15 | prainha
# Processing Record 16 of Set 15 | batticaloa
# Processing Record 17 of Set 15 | cooma
# Processing Record 18 of Set 15 | mezen
# Processing Record 19 of Set 15 | aswan
# Processing Record 20 of Set 15 | yenagoa
# Processing Record 21 of Set 15 | velikiy ustyug
# Processing Record 22 of Set 15 | ouesso
# Processing Record 23 of Set 15 | bembereke
# Processing Record 24 of Set 15 | boyolangu
# Processing Record 25 of Set 15 | alvorada
# Processing Record 26 of Set 15 | pacasmayo
# Processing Record 27 of Set 15 | lakatoro
# Processing Record 28 of Set 15 | doha
# Processing Record 29 of Set 15 | kanniyakumari
# Processing Record 30 of Set 15 | sartana
# Processing Record 31 of Set 15 | bratsk
# Processing Record 32 of Set 15 | olkhovka
# Processing Record 33 of Set 15 | nuuk
# Processing Record 34 of Set 15 | brasilia de minas
# Processing Record 35 of Set 15 | mporokoso
# Processing Record 36 of Set 15 | ravar
# Processing Record 37 of Set 15 | yangambi
# Processing Record 38 of Set 15 | riverton
# Processing Record 39 of Set 15 | fomboni
# Processing Record 40 of Set 15 | portland
# Processing Record 41 of Set 15 | raymond
# Processing Record 42 of Set 15 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 43 of Set 15 | fuyu
# Processing Record 44 of Set 15 | priargunsk
# Processing Record 45 of Set 15 | gizo
# Processing Record 46 of Set 15 | belawan
# Processing Record 47 of Set 15 | casper
# Processing Record 48 of Set 15 | sydney
# Processing Record 49 of Set 15 | vestmanna
# Processing Record 50 of Set 15 | nouakchott
# Processing Record 1 of Set 16 | arman
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert array of dict to Pandas
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Albany  42.6001  -73.9662     16.45        45          33
# 1        Sechura  -5.5569  -80.8222     80.42        57          93
# 2      Jamestown  42.0970  -79.2353     14.52        35           0
# 3  Cockburn Town  21.4612  -71.1419     78.76        73          40
# 4          Vaini -21.2000 -175.2000     80.33        69          94
#
#    Wind Speed Country Current Description
# 0        1.01      US    scattered clouds
# 1       13.56      PE     overcast clouds
# 2       12.66      US           clear sky
# 3        6.91      TC    scattered clouds
# 4       15.28      TO     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Albany      US  42.6001  -73.9662     16.45        45          33
# 1        Sechura      PE  -5.5569  -80.8222     80.42        57          93
# 2      Jamestown      US  42.0970  -79.2353     14.52        35           0
# 3  Cockburn Town      TC  21.4612  -71.1419     78.76        73          40
# 4          Vaini      TO -21.2000 -175.2000     80.33        69          94
# 5     Sao Filipe      CV  14.8961  -24.4956     72.75        70         100
# 6        Fortuna      US  40.5982 -124.1573     56.48        85          75
# 7     Chhindwara      IN  22.0667   78.9333     59.97        40           5
# 8  Leningradskiy      RU  69.3833  178.4167    -16.64        90          71
# 9      Saskylakh      RU  71.9167  114.0833    -19.98        86          93
#
#    Wind Speed Current Description
# 0        1.01    scattered clouds
# 1       13.56     overcast clouds
# 2       12.66           clear sky
# 3        6.91    scattered clouds
# 4       15.28     overcast clouds
# 5        8.50     overcast clouds
# 6       10.36       broken clouds
# 7        3.83           clear sky
# 8        5.66       broken clouds
# 9        2.42     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/weatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
